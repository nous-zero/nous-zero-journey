# %%
# ================================================
# Cell 1: 오늘의 학습 설정 (매일 이것만 수정!)
# ================================================

# 🔵 [1] 한 줄 요약 (자유 텍스트)
TODAY_MEMO    = "LeetCode #26 Remove Duplicates from Sorted Array"

# 🔵 [2] DEV.to 태그 (소문자, 공백 없음, 최대 4개)
TAGS          = ["python", "leetcode", "array"]

# 🔵 [3] Drive 작업 노트북 파일명 (고정 — 절대 수정하지 말 것)
NOTEBOOK_NAME = "daily_working_leetcode.ipynb"

# 🔵 [4] 학습 주제 — 단계에 맞춰 수정
# 허용값: "Array" "String" "Stack" "LinkedList" "HashMap" "BinarySearch"
TOPIC         = "Array"

# 🔵 [5] 파일명 라벨 (영문/숫자/언더스코어/하이픈만 — 슬래시·공백·# 금지)
# 자동으로 앞에 "{날짜}_"가 붙습니다.
# 예: "LeetCode26_RemoveDuplicates" → "2026-05-07_LeetCode26_RemoveDuplicates.ipynb"
FILE_LABEL    = "LeetCode26_RemoveDuplicates"

# --- 셀 1 검증: 위험 문자 차단 ---
import re
_FORBIDDEN = re.compile(r"[\/\\#\s]")
for _name, _val in [("NOTEBOOK_NAME", NOTEBOOK_NAME), ("TOPIC", TOPIC), ("FILE_LABEL", FILE_LABEL)]:
    if _FORBIDDEN.search(_val):
        raise ValueError(f"❌ {_name}에 금지 문자 포함: {_val!r} — 슬래시/백슬래시/#/공백 제거 필요")
print("✅ 셀 1 검증 통과")
# Out:
# ✅ 셀 1 검증 통과

# %% [markdown]
# ## 오늘 배운 것
#
# **LeetCode #26 — Remove Duplicates from Sorted Array (Easy)**
#
# 정렬된 배열에서 중복을 제거하고(in-place), 고유 원소의 개수 `k`를 반환하는 문제.
#
# - **투 포인터(two-pointer) 기법**: 포인터 두 개를 따로 굴린다.
#   - `i` (읽기 포인터): `for`문으로 배열 전체를 1번 칸부터 순서대로 훑는다.
#   - `write_index` (쓰기 포인터): 고유값을 채워 넣을 위치. 새 값을 쓸 때마다 한 칸 전진.
# - `nums[i] != nums[i-1]` → 현재 칸 값 ≠ 바로 왼쪽 칸 값. 배열이 *정렬*돼 있으므로, 직전 값과 다르면 처음 보는 새 고유값이다.
# - `write_index = 1`로 시작하는 이유: 0번 칸에는 이미 첫 고유값(`nums[0]`)이 있어 다시 쓸 필요가 없다. 두 번째 고유값부터 채울 1번 칸이 시작점.
# - `write_index += 1`: 한 칸 채웠으면 포인터를 옮겨야 다음 값이 *다음 칸*에 들어간다. 안 옮기면 덮어쓰기로 이전 값이 사라진다.
#
# **함께 정리한 Python 기초 개념**
#
# - `for`문: 시퀀스의 각 항목을 순서대로 빠짐없이 반복. 반복 변수 `i`는 `for`문이 자동으로 만들어 준다(따로 `i = 0` 불필요).
# - `if`문: 함수가 아니라 **조건문**. 조건이 참일 때만 들여쓴 블록을 실행한다.
# - `==`(같다, 비교) ↔ `=`(대입)은 다르다. `!=`는 "같지 않다". Python에서 `!` 하나만으로는 연산자가 아니다(논리 부정은 `not`).
# - `for`, `if` 문은 `:` 콜론으로 끝내고, 다음 줄부터 들여쓰기로 블록을 만든다.
#
# ## 핵심 코드
#
# ```python
# class Solution:
#     def removeDuplicates(self, nums: list[int]) -> int:
#         write_index = 1
#         for i in range(1, len(nums)):
#             if nums[i] != nums[i - 1]:
#                 nums[write_index] = nums[i]
#                 write_index += 1
#         return write_index
# ```
#
# - `range(1, len(nums))` — 0번 칸은 비교 대상이 없으므로 1번 칸부터 훑는다.
# - `nums[i] != nums[i-1]`이 참이면 새 고유값 → `write_index` 칸에 복사하고 포인터 전진.
# - 거짓(중복)이면 아무것도 안 하고 건너뛴다.
# - 마지막에 `write_index`(채워 넣은 고유값 개수 = `k`)를 반환.
# - 결과: 배열 앞쪽 `k`칸에 고유값이 정렬된 채 남는다. Runtime 0 ms로 Accepted.
#
# ## 회고
#
# 처음 작성한 코드에는 실수가 5개 있었다 — 입력 배열 덮어쓰기, `if i=0`(불필요 + 문법 오류), 콜론 누락 2곳, `if` 블록 본문 비어 있음. 하나씩 고쳐 정답을 완성했지만, 제출 단계에서 `IndentationError`가 또 났다. 코드가 틀린 게 아니라 복사·붙여넣기 과정에서 들여쓰기가 어긋난 환경 문제였다.
#
# 오늘 가장 크게 느낀 것: 알고리즘을 모르는 게 아니라, 한국어로 이해한 내용을 Python 문법으로 "번역"하는 단계에서 막힌다는 것. write_index 로직을 말로는 정확히 설명했는데 코드로는 한 줄도 못 옮겼던 게 그 증거다. 에러 메시지를 "실패"가 아니라 "어디를 고치라는 안내"로 읽는 연습도 됐다.

# %%
# ================================================
# 🔵 학습 코드 — 여기에 오늘 공부한 코드를 작성
# ================================================

class Solution:
    def removeDuplicates(self, nums: list[int]) -> int:
        write_index = 1
        for i in range(1, len(nums)):
            if nums[i] != nums[i - 1]:
                nums[write_index] = nums[i]
                write_index += 1
        return write_index

# %%
# ================================================
# Cell 4: Drive 마운트 + GitHub repo 준비 (한 번만 실행)
# ================================================
from google.colab import drive
drive.mount('/content/drive')

import subprocess, os
from google.colab import userdata

GITHUB_TOKEN = userdata.get('GITHUB_TOKEN').strip()
GITHUB_USER  = "nous-zero"
GITHUB_REPO  = "nous-zero-journey"
REPO_PATH    = f"/content/{GITHUB_REPO}"

if not os.path.exists(REPO_PATH):
    repo_url = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"
    subprocess.run(["git", "clone", repo_url, REPO_PATH], check=True)
    print(f"✅ Repo 클론 완료: {REPO_PATH}")
else:
    print(f"✅ Repo 이미 존재: {REPO_PATH}")

# %%
# ================================================
# Cell 5: 원클릭 배포 + 셀 2·3 자동 초기화
# - Phase0_기초/{TOPIC}/{날짜}_{FILE_LABEL}.ipynb 저장
# - logs/{날짜}/summary.md 생성
# - git push 성공 시에만 셀 2·3 비움 (학습 내용 보호)
# ================================================
import subprocess, shutil, os, json, re
from datetime import datetime
from google.colab import userdata
import nbformat

GITHUB_TOKEN = userdata.get('GITHUB_TOKEN').strip()
GITHUB_USER  = "nous-zero"
GITHUB_REPO  = "nous-zero-journey"
REPO_PATH    = f"/content/{GITHUB_REPO}"
today        = datetime.now().strftime("%Y-%m-%d")

TOPIC_DIR    = f"{REPO_PATH}/Phase0_기초/{TOPIC}"
LOG_DIR      = f"{REPO_PATH}/logs/{today}"
TARGET_FILE  = f"{today}_{FILE_LABEL}.ipynb"

# --- 1. remote URL 업데이트 ---
new_url = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"
subprocess.run(["git", "-C", REPO_PATH, "remote", "set-url", "origin", new_url])

# --- 2. 최신 상태 pull ---
subprocess.run(["git", "-C", REPO_PATH, "pull"], capture_output=True, text=True)

# --- 3. 노트북 파싱 ---
def extract_summary_from_notebook(nb_path):
    with open(nb_path, 'r', encoding='utf-8') as f:
        nb = json.load(f)
    markdown_content, code_snippets = [], []
    for cell in nb.get('cells', []):
        source = ''.join(cell.get('source', []))
        if cell['cell_type'] == 'markdown':
            if any(skip in source for skip in [
                'Daily Study Template', 'Cell 0', 'Cell 1',
                '색상 안내', '학습 내용 작성', '마지막 셀'
            ]):
                continue
            markdown_content.append(source)
        elif cell['cell_type'] == 'code':
            if any(skip in source for skip in [
                'GITHUB_TOKEN', 'drive.mount', 'subprocess.run(["git"',
                'shutil.copy', 'extract_summary_from_notebook', 'TOPIC_DIR',
                'TODAY_MEMO', 'NOTEBOOK_NAME', 'TAGS =', 'FILE_LABEL',
                'nbformat', '_FORBIDDEN'
            ]):
                continue
            stripped = re.sub(r'#.*', '', source).strip()
            if stripped and len(source.strip()) > 20:
                code_snippets.append(source.strip())
    return markdown_content, code_snippets

def generate_summary_md(markdown_parts, code_parts):
    tags_str = json.dumps(TAGS)
    relative_nb_path = f"../../Phase0_기초/{TOPIC}/{TARGET_FILE}"
    summary = f"""---
title: "[{today}] {TODAY_MEMO}"
tags: {tags_str}
---

"""
    if markdown_parts:
        for md in markdown_parts:
            summary += md + "\n\n"
    else:
        summary += f"## 오늘 배운 것\n\n{TODAY_MEMO}\n\n"
    summary += f"## 작업 파일\n\n- [{TARGET_FILE}]({relative_nb_path})\n\n"
    if code_parts:
        summary += "## 핵심 코드\n\n"
        for code in code_parts[:2]:
            lines = code.split('\n')
            if len(lines) > 30:
                code = '\n'.join(lines[:30]) + '\n# ... (계속)'
            summary += f"```python\n{code}\n```\n\n"
    return summary

# --- 4. 노트북을 주제별 폴더에 저장 ---
notebook_path = f"/content/drive/MyDrive/Colab Notebooks/{NOTEBOOK_NAME}"
os.makedirs(TOPIC_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

if os.path.exists(notebook_path):
    target_path = f"{TOPIC_DIR}/{TARGET_FILE}"
    shutil.copy(notebook_path, target_path)
    print(f"✅ 노트북 저장: Phase0_기초/{TOPIC}/{TARGET_FILE}")
    md_parts, code_parts = extract_summary_from_notebook(notebook_path)
    summary_content = generate_summary_md(md_parts, code_parts)
else:
    print(f"⚠️ 노트북을 찾을 수 없습니다: {notebook_path}")
    summary_content = generate_summary_md([], [])

with open(f"{LOG_DIR}/summary.md", 'w', encoding='utf-8') as f:
    f.write(summary_content)
print(f"✅ 요약 저장: logs/{today}/summary.md")

# --- 5. Git 커밋 & 푸시 ---
subprocess.run(["git", "config", "--global", "--add", "safe.directory", REPO_PATH])
os.chdir(REPO_PATH)

# ✅ [추가] git 작성자 정보 설정 — 없으면 "Author identity unknown"으로 commit 실패
subprocess.run(["git", "config", "--global", "user.email", "nous-zero@users.noreply.github.com"])
subprocess.run(["git", "config", "--global", "user.name", "nous-zero"])
commit_message = f"[{today}] {TODAY_MEMO}"

push_result = None
for cmd in [["git", "add", "."], ["git", "commit", "-m", commit_message], ["git", "push"]]:
    result = subprocess.run(cmd, capture_output=True, text=True)
    if cmd[1] == "push":
        push_result = result
    if result.returncode != 0 and 'nothing to commit' not in result.stderr:
        print(f"⚠️ {' '.join(cmd[:2])}: {result.stderr.strip()}")
    else:
        print(f"✅ {' '.join(cmd[:2])} 완료")

# --- 6. 셀 2·3 자동 초기화 (push 성공 시에만) ---
LEARNING_MARKERS  = ["오늘 배운 것", "학습 코드 — 여기에", "회고"]
PROTECTED_MARKERS = [
    "GITHUB_TOKEN", "TODAY_MEMO =", "TAGS =", "NOTEBOOK_NAME =",
    "TOPIC =", "FILE_LABEL =", "subprocess.run", "shutil.copy",
    "extract_summary_from_notebook", "nbformat", "_FORBIDDEN",
    "drive.mount"
]
DEFAULT_MARKDOWN = """## 오늘 배운 것

여기에 오늘 학습한 내용을 마크다운으로 작성하세요.

- 배운 개념 1
- 배운 개념 2

## 핵심 코드

핵심 코드 설명을 작성하세요.

## 회고

오늘 학습에 대한 짧은 회고를 작성하세요.
"""
DEFAULT_CODE = """# ================================================
# 🔵 학습 코드 — 여기에 오늘 공부한 코드를 작성
# ================================================

"""

def reset_learning_cells(nb_path):
    if not os.path.exists(nb_path):
        print(f"⚠️ 초기화 대상 노트북 없음: {nb_path}")
        return False
    try:
        with open(nb_path, 'r', encoding='utf-8') as f:
            nb = nbformat.read(f, as_version=4)
        reset_count = 0
        for cell in nb.cells:
            src = cell.source if isinstance(cell.source, str) else ''.join(cell.source)
            is_learning  = any(m in src for m in LEARNING_MARKERS)
            is_protected = any(m in src for m in PROTECTED_MARKERS)
            if is_learning and not is_protected:
                if cell.cell_type == 'markdown':
                    cell.source = DEFAULT_MARKDOWN
                elif cell.cell_type == 'code':
                    cell.source = DEFAULT_CODE
                    cell.outputs = []
                    cell.execution_count = None
                reset_count += 1
        if reset_count == 0:
            print("⚠️ 학습 내용 셀을 찾지 못함")
            return False
        with open(nb_path, 'w', encoding='utf-8') as f:
            nbformat.write(nb, f)
        print(f"✅ 셀 초기화 완료: {reset_count}개 셀 비움")
        return True
    except Exception as e:
        print(f"⚠️ 초기화 중 오류: {e}")
        return False

push_ok = (push_result is not None) and (
    push_result.returncode == 0 or 'up-to-date' in (push_result.stderr or '')
)
if push_ok:
    print("\n📝 학습 내용 셀 초기화 중...")
    reset_learning_cells(notebook_path)
    print("⚠️ 다음 학습 전: Colab에서 이 노트북을 닫고 다시 열어주세요")
else:
    print("\n🛑 git push 실패 → 셀 초기화 건너뜀 (학습 내용 보호)")

print(f"\n🎉 배포 완료!")
print(f"   커밋: {commit_message}")
print(f"   파일: Phase0_기초/{TOPIC}/{TARGET_FILE}")
print(f"   요약: logs/{today}/summary.md")
print(f"   GitHub: https://github.com/{GITHUB_USER}/{GITHUB_REPO}")
